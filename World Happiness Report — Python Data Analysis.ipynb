# %%
# Out:
# Libraries loaded successfully.
#  Dataset loaded: 2363 rows × 11 columns
# ...
# DATASET OVERVIEW
# ...
#
# Shape        : (2363, 11)
# Years Covered: 2005 – 2023
# Countries    : 165
#
# Missing Values:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   28
# Social support                       13
# Healthy life expectancy at birth     63
# Freedom to make life choices         36
# Generosity                           81
# Perceptions of corruption           125
# Positive affect                      24
# Negative affect                      16
# dtype: int64
# Cleaning Data...
#    Duplicates removed
#    Rows with critical missing values dropped
#    Clean dataset shape: (2270, 11)
#
#  Latest year for country analysis: 2023
#    Countries in latest year: 128
# Chart saved: 01_top_bottom_countries.png
# Chart saved: 02_gdp_vs_happiness.png
# Chart saved: 03_happiness_vs_gdp.png
# ...
